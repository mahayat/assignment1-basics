# %%
import regex as re
# from tobenamed import get_chunks, train_bpe, PAT, get_pretokens, get_stories, get_pretoken_bytes
#get_all_pretokens, get_pretoken_counter

# %%
input_path = "../data/TinyStoriesV2-GPT4-valid.txt"
vocab_size = 265
special_tokens = ["<|endoftext|>"]
# num_processes = 20
# split_special_token = "<|endoftext|>"

# %%
# from tobenamed import TrainBPE

# trainer = TrainBPE(input_path, vocab_size, special_tokens)
# vocab, merge = trainer.train_bpe()

# %%
from tobenamed import train_bpe
vocab, merges = train_bpe(input_path, vocab_size, special_tokens)

# %%
merges
# Out:
# [(b' ', b't'),
#  (b'h', b'e'),
#  (b' ', b'a'),
#  (b' ', b's'),
#  (b' ', b'w'),
#  (b' t', b'he'),
#  (b'n', b'd'),
#  (b'e', b'd')]

# %%
import cProfile
cProfile.run('train_bpe(input_path, vocab_size, special_tokens)')
# Out:
#          47011204 function calls (47011196 primitive calls) in 12.652 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:263(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:312(__init__)
#         1    0.000    0.000    0.010    0.010 <frozen codecs>:322(decode)
#     27636    0.010    0.000    0.014    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.009    0.009    8.678    8.678 <string>:1(<module>)
#         1    0.000    0.000    0.001    0.001 asyncio.py:206(_handle_events)
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         4    0.000    0.000    0.001    0.000 attrsettr.py:43(__getattr__)
#         4    0.001    0.000    0.001    0.000 attrsettr.py:66(_get_attr_opt)
# ...
