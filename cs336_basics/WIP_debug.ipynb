# %%
import regex as re
# from tobenamed import get_chunks, train_bpe, PAT, get_pretokens, get_stories, get_pretoken_bytes
#get_all_pretokens, get_pretoken_counter

# %%
input_path = "../data/TinyStoriesV2-GPT4-valid.txt"
vocab_size = 265
special_tokens = ["<|endoftext|>"]
# num_processes = 20
# split_special_token = "<|endoftext|>"

# %%
from tobenamed import TrainBPE

trainer = TrainBPE(input_path, vocab_size, special_tokens)
# vocab, merge = trainer.train_bpe()

# %%
vocab, merges = trainer.train_bpe()
# Out:
# merge_num: 0, most_frequent_pair: (32, 116), new_token: b' t'
# merge_num: 1, most_frequent_pair: (104, 101), new_token: b'he'
# merge_num: 2, most_frequent_pair: (32, 97), new_token: b' a'
# merge_num: 3, most_frequent_pair: (32, 115), new_token: b' s'
# merge_num: 4, most_frequent_pair: (32, 119), new_token: b' w'
# merge_num: 5, most_frequent_pair: (257, 258), new_token: b' the'
# merge_num: 6, most_frequent_pair: (110, 100), new_token: b'nd'
# merge_num: 7, most_frequent_pair: (101, 100), new_token: b'ed'

# %%
merges
# Out:
# [(b' ', b't'),
#  (b'h', b'e'),
#  (b' ', b'a'),
#  (b' ', b's'),
#  (b' ', b'w'),
#  (b' t', b'he'),
#  (b'n', b'd'),
#  (b'e', b'd')]
