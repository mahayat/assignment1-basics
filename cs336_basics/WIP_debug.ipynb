# %%
import regex as re
from tobenamed import get_chunks, train_bpe, PAT, get_pretokens, get_stories, get_pretoken_bytes
#get_all_pretokens, get_pretoken_counter

# %%
input_path = "../data/TinyStoriesV2-GPT4-valid.txt"
vocab_size = 500
special_tokens = ["<|endoftext|>"]
# num_processes = 20
# split_special_token = "<|endoftext|>"

# %%
from tobenamed import train_bpe
vocab, merges = train_bpe(input_path, vocab_size, special_tokens)
# Out:
# merge_num: 0, most_frequent_pair: (104, 101), new_token: b'he'
# merge_num: 1, most_frequent_pair: (32, 116), new_token: b' t'
# merge_num: 2, most_frequent_pair: (32, 97), new_token: b' a'
# merge_num: 3, most_frequent_pair: (32, 115), new_token: b' s'
# merge_num: 4, most_frequent_pair: (32, 119), new_token: b' w'
# merge_num: 5, most_frequent_pair: (110, 100), new_token: b'nd'
# merge_num: 6, most_frequent_pair: (258, 257), new_token: b' the'
# merge_num: 7, most_frequent_pair: (101, 100), new_token: b'ed'
# merge_num: 8, most_frequent_pair: (32, 98), new_token: b' b'
# merge_num: 9, most_frequent_pair: (258, 111), new_token: b' to'
# merge_num: 10, most_frequent_pair: (259, 262), new_token: b' and'
# merge_num: 11, most_frequent_pair: (32, 104), new_token: b' h'
# merge_num: 12, most_frequent_pair: (32, 102), new_token: b' f'
# merge_num: 13, most_frequent_pair: (105, 110), new_token: b'in'
# merge_num: 14, most_frequent_pair: (261, 97), new_token: b' wa'
# merge_num: 15, most_frequent_pair: (32, 84), new_token: b' T'
# merge_num: 16, most_frequent_pair: (114, 101), new_token: b're'
# merge_num: 17, most_frequent_pair: (105, 116), new_token: b'it'
# merge_num: 18, most_frequent_pair: (111, 117), new_token: b'ou'
# merge_num: 19, most_frequent_pair: (32, 108), new_token: b' l'
# merge_num: 20, most_frequent_pair: (32, 100), new_token: b' d'
# merge_num: 21, most_frequent_pair: (32, 99), new_token: b' c'
# merge_num: 22, most_frequent_pair: (32, 112), new_token: b' p'
# merge_num: 23, most_frequent_pair: (97, 121), new_token: b'ay'
# merge_num: 24, most_frequent_pair: (271, 115), new_token: b' was'
# merge_num: 25, most_frequent_pair: (101, 114), new_token: b'er'
# merge_num: 26, most_frequent_pair: (32, 109), new_token: b' m'
# merge_num: 27, most_frequent_pair: (111, 109), new_token: b'om'
# merge_num: 28, most_frequent_pair: (32, 257), new_token: b' he'
# merge_num: 29, most_frequent_pair: (272, 257), new_token: b' The'
# merge_num: 30, most_frequent_pair: (105, 115), new_token: b'is'
# merge_num: 31, most_frequent_pair: (32, 110), new_token: b' n'
# merge_num: 32, most_frequent_pair: (111, 110), new_token: b'on'
# merge_num: 33, most_frequent_pair: (260, 97), new_token: b' sa'
# merge_num: 34, most_frequent_pair: (108, 108), new_token: b'll'
# merge_num: 35, most_frequent_pair: (105, 109), new_token: b'im'
# merge_num: 36, most_frequent_pair: (97, 114), new_token: b'ar'
# merge_num: 37, most_frequent_pair: (105, 100), new_token: b'id'
# merge_num: 38, most_frequent_pair: (268, 97), new_token: b' ha'
# merge_num: 39, most_frequent_pair: (32, 83), new_token: b' S'
# merge_num: 40, most_frequent_pair: (32, 103), new_token: b' g'
# merge_num: 41, most_frequent_pair: (97, 116), new_token: b'at'
# merge_num: 42, most_frequent_pair: (270, 103), new_token: b'ing'
# merge_num: 43, most_frequent_pair: (111, 116), new_token: b'ot'
# merge_num: 44, most_frequent_pair: (101, 110), new_token: b'en'
# merge_num: 45, most_frequent_pair: (97, 110), new_token: b'an'
# merge_num: 46, most_frequent_pair: (108, 101), new_token: b'le'
# merge_num: 47, most_frequent_pair: (111, 114), new_token: b'or'
# merge_num: 48, most_frequent_pair: (105, 114), new_token: b'ir'
# merge_num: 49, most_frequent_pair: (32, 72), new_token: b' H'
# merge_num: 50, most_frequent_pair: (97, 109), new_token: b'am'
# merge_num: 51, most_frequent_pair: (101, 116), new_token: b'et'
# merge_num: 52, most_frequent_pair: (258, 104), new_token: b' th'
# merge_num: 53, most_frequent_pair: (32, 274), new_token: b' it'
# merge_num: 54, most_frequent_pair: (105, 103), new_token: b'ig'
# merge_num: 55, most_frequent_pair: (105, 108), new_token: b'il'
# merge_num: 56, most_frequent_pair: (286, 121), new_token: b' They'
# merge_num: 57, most_frequent_pair: (306, 101), new_token: b' He'
# merge_num: 58, most_frequent_pair: (32, 270), new_token: b' in'
# merge_num: 59, most_frequent_pair: (32, 34), new_token: b' "'
# merge_num: 60, most_frequent_pair: (279, 108), new_token: b' pl'
# merge_num: 61, most_frequent_pair: (114, 105), new_token: b'ri'
# merge_num: 62, most_frequent_pair: (118, 282), new_token: b'ver'
# merge_num: 63, most_frequent_pair: (111, 119), new_token: b'ow'
# merge_num: 64, most_frequent_pair: (32, 117), new_token: b' u'
# merge_num: 65, most_frequent_pair: (117, 116), new_token: b'ut'
# merge_num: 66, most_frequent_pair: (277, 280), new_token: b' day'
# merge_num: 67, most_frequent_pair: (290, 294), new_token: b' said'
# merge_num: 68, most_frequent_pair: (112, 112), new_token: b'pp'
# merge_num: 69, most_frequent_pair: (32, 121), new_token: b' y'
# merge_num: 70, most_frequent_pair: (101, 115), new_token: b'es'
# merge_num: 71, most_frequent_pair: (274, 104), new_token: b'ith'
# merge_num: 72, most_frequent_pair: (79, 110), new_token: b'On'
# merge_num: 73, most_frequent_pair: (261, 328), new_token: b' with'
# merge_num: 74, most_frequent_pair: (317, 280), new_token: b' play'
# merge_num: 75, most_frequent_pair: (32, 111), new_token: b' o'
# merge_num: 76, most_frequent_pair: (111, 111), new_token: b'oo'
# merge_num: 77, most_frequent_pair: (285, 114), new_token: b' her'
# merge_num: 78, most_frequent_pair: (107, 264), new_token: b'ked'
# merge_num: 79, most_frequent_pair: (32, 114), new_token: b' r'
# merge_num: 80, most_frequent_pair: (32, 73), new_token: b' I'
# merge_num: 81, most_frequent_pair: (296, 257), new_token: b' She'
# merge_num: 82, most_frequent_pair: (268, 287), new_token: b' his'
# merge_num: 83, most_frequent_pair: (265, 101), new_token: b' be'
# merge_num: 84, most_frequent_pair: (260, 116), new_token: b' st'
# merge_num: 85, most_frequent_pair: (108, 100), new_token: b'ld'
# merge_num: 86, most_frequent_pair: (272, 292), new_token: b' Tim'
# merge_num: 87, most_frequent_pair: (99, 101), new_token: b'ce'
# merge_num: 88, most_frequent_pair: (110, 116), new_token: b'nt'
# merge_num: 89, most_frequent_pair: (32, 101), new_token: b' e'
# merge_num: 90, most_frequent_pair: (265, 311), new_token: b' big'
# merge_num: 91, most_frequent_pair: (99, 107), new_token: b'ck'
# merge_num: 92, most_frequent_pair: (326, 275), new_token: b' you'
# merge_num: 93, most_frequent_pair: (319, 121), new_token: b'very'
# merge_num: 94, most_frequent_pair: (107, 101), new_token: b'ke'
# merge_num: 95, most_frequent_pair: (295, 325), new_token: b' happ'
# merge_num: 96, most_frequent_pair: (101, 262), new_token: b'end'
# merge_num: 97, most_frequent_pair: (32, 289), new_token: b' on'
# merge_num: 98, most_frequent_pair: (118, 101), new_token: b've'
# merge_num: 99, most_frequent_pair: (117, 110), new_token: b'un'
# merge_num: 100, most_frequent_pair: (97, 291), new_token: b'all'
# merge_num: 101, most_frequent_pair: (312, 121), new_token: b'ily'
# merge_num: 102, most_frequent_pair: (32, 76), new_token: b' L'
# merge_num: 103, most_frequent_pair: (318, 353), new_token: b'riend'
# merge_num: 104, most_frequent_pair: (269, 360), new_token: b' friend'
# merge_num: 105, most_frequent_pair: (321, 112), new_token: b' up'
# merge_num: 106, most_frequent_pair: (271, 345), new_token: b' want'
# merge_num: 107, most_frequent_pair: (276, 105), new_token: b' li'
# merge_num: 108, most_frequent_pair: (263, 121), new_token: b' they'
# merge_num: 109, most_frequent_pair: (295, 100), new_token: b' had'
# merge_num: 110, most_frequent_pair: (277, 111), new_token: b' do'
# merge_num: 111, most_frequent_pair: (261, 101), new_token: b' we'
# merge_num: 112, most_frequent_pair: (288, 300), new_token: b' not'
# merge_num: 113, most_frequent_pair: (257, 114), new_token: b'her'
# merge_num: 114, most_frequent_pair: (274, 116), new_token: b'itt'
# merge_num: 115, most_frequent_pair: (332, 102), new_token: b' of'
# merge_num: 116, most_frequent_pair: (32, 66), new_token: b' B'
# merge_num: 117, most_frequent_pair: (97, 100), new_token: b'ad'
# merge_num: 118, most_frequent_pair: (352, 121), new_token: b' happy'
# merge_num: 119, most_frequent_pair: (115, 116), new_token: b'st'
# merge_num: 120, most_frequent_pair: (32, 77), new_token: b' M'
# merge_num: 121, most_frequent_pair: (309, 298), new_token: b' that'
# merge_num: 122, most_frequent_pair: (115, 101), new_token: b'se'
# merge_num: 123, most_frequent_pair: (290, 119), new_token: b' saw'
# merge_num: 124, most_frequent_pair: (329, 101), new_token: b'One'
# merge_num: 125, most_frequent_pair: (283, 284), new_token: b' mom'
# merge_num: 126, most_frequent_pair: (301, 116), new_token: b'ent'
# merge_num: 127, most_frequent_pair: (32, 350), new_token: b' very'
# merge_num: 128, most_frequent_pair: (371, 303), new_token: b'ittle'
# merge_num: 129, most_frequent_pair: (276, 385), new_token: b' little'
# merge_num: 130, most_frequent_pair: (275, 342), new_token: b'ould'
# merge_num: 131, most_frequent_pair: (269, 304), new_token: b' for'
# merge_num: 132, most_frequent_pair: (39, 115), new_token: b"'s"
# merge_num: 133, most_frequent_pair: (260, 111), new_token: b' so'
# merge_num: 134, most_frequent_pair: (260, 257), new_token: b' she'
# merge_num: 135, most_frequent_pair: (260, 104), new_token: b' sh'
# merge_num: 136, most_frequent_pair: (292, 101), new_token: b'ime'
# merge_num: 137, most_frequent_pair: (258, 393), new_token: b' time'
# merge_num: 138, most_frequent_pair: (46, 34), new_token: b'."'
# merge_num: 139, most_frequent_pair: (288, 307), new_token: b' nam'
# merge_num: 140, most_frequent_pair: (265, 111), new_token: b' bo'
# merge_num: 141, most_frequent_pair: (99, 104), new_token: b'ch'
# merge_num: 142, most_frequent_pair: (32, 107), new_token: b' k'
# merge_num: 143, most_frequent_pair: (288, 101), new_token: b' ne'
# merge_num: 144, most_frequent_pair: (263, 273), new_token: b' there'
# merge_num: 145, most_frequent_pair: (305, 100), new_token: b'ird'
# merge_num: 146, most_frequent_pair: (275, 262), new_token: b'ound'
# merge_num: 147, most_frequent_pair: (359, 358), new_token: b' Lily'
# merge_num: 148, most_frequent_pair: (396, 264), new_token: b' named'
# merge_num: 149, most_frequent_pair: (265, 402), new_token: b' bird'
# merge_num: 150, most_frequent_pair: (260, 109), new_token: b' sm'
# merge_num: 151, most_frequent_pair: (363, 264), new_token: b' wanted'
# merge_num: 152, most_frequent_pair: (361, 115), new_token: b' friends'
# merge_num: 153, most_frequent_pair: (118, 264), new_token: b'ved'
# merge_num: 154, most_frequent_pair: (368, 273), new_token: b' were'
# merge_num: 155, most_frequent_pair: (272, 284), new_token: b' Tom'
# merge_num: 156, most_frequent_pair: (84, 257), new_token: b'The'
# merge_num: 157, most_frequent_pair: (265, 322), new_token: b' but'
# merge_num: 158, most_frequent_pair: (275, 116), new_token: b'out'
# merge_num: 159, most_frequent_pair: (33, 34), new_token: b'!"'
# merge_num: 160, most_frequent_pair: (259, 110), new_token: b' an'
# merge_num: 161, most_frequent_pair: (101, 108), new_token: b'el'
# merge_num: 162, most_frequent_pair: (104, 116), new_token: b'ht'
# merge_num: 163, most_frequent_pair: (108, 112), new_token: b'lp'
# merge_num: 164, most_frequent_pair: (266, 111), new_token: b' too'
# merge_num: 165, most_frequent_pair: (294, 101), new_token: b'ide'
# merge_num: 166, most_frequent_pair: (97, 108), new_token: b'al'
# merge_num: 167, most_frequent_pair: (285, 420), new_token: b' help'
# merge_num: 168, most_frequent_pair: (337, 116), new_token: b' It'
# merge_num: 169, most_frequent_pair: (329, 344), new_token: b'Once'
# merge_num: 170, most_frequent_pair: (259, 291), new_token: b' all'
# merge_num: 171, most_frequent_pair: (261, 104), new_token: b' wh'
# merge_num: 172, most_frequent_pair: (284, 101), new_token: b'ome'
# merge_num: 173, most_frequent_pair: (32, 65), new_token: b' A'
# merge_num: 174, most_frequent_pair: (261, 383), new_token: b' went'
# merge_num: 175, most_frequent_pair: (276, 111), new_token: b' lo'
# merge_num: 176, most_frequent_pair: (117, 103), new_token: b'ug'
# merge_num: 177, most_frequent_pair: (276, 333), new_token: b' loo'
# merge_num: 178, most_frequent_pair: (32, 287), new_token: b' is'
# merge_num: 179, most_frequent_pair: (362, 289), new_token: b' upon'
# merge_num: 180, most_frequent_pair: (97, 351), new_token: b'ake'
# merge_num: 181, most_frequent_pair: (116, 282), new_token: b'ter'
# merge_num: 182, most_frequent_pair: (114, 121), new_token: b'ry'
# merge_num: 183, most_frequent_pair: (117, 101), new_token: b'ue'
# merge_num: 184, most_frequent_pair: (111, 273), new_token: b'ore'
# merge_num: 185, most_frequent_pair: (266, 121), new_token: b' toy'
# merge_num: 186, most_frequent_pair: (269, 356), new_token: b' fun'
# merge_num: 187, most_frequent_pair: (103, 308), new_token: b'get'
# merge_num: 188, most_frequent_pair: (105, 291), new_token: b'ill'
# merge_num: 189, most_frequent_pair: (105, 262), new_token: b'ind'
# merge_num: 190, most_frequent_pair: (444, 370), new_token: b'gether'
# merge_num: 191, most_frequent_pair: (278, 298), new_token: b' cat'
# merge_num: 192, most_frequent_pair: (259, 115), new_token: b' as'
# merge_num: 193, most_frequent_pair: (265, 97), new_token: b' ba'
# merge_num: 194, most_frequent_pair: (259, 116), new_token: b' at'
# merge_num: 195, most_frequent_pair: (32, 273), new_token: b' re'
# merge_num: 196, most_frequent_pair: (307, 101), new_token: b'ame'
# merge_num: 197, most_frequent_pair: (266, 447), new_token: b' together'
# merge_num: 198, most_frequent_pair: (32, 106), new_token: b' j'
# merge_num: 199, most_frequent_pair: (277, 294), new_token: b' did'
# merge_num: 200, most_frequent_pair: (117, 114), new_token: b'ur'
# merge_num: 201, most_frequent_pair: (367, 103), new_token: b' dog'
# merge_num: 202, most_frequent_pair: (258, 273), new_token: b' tre'
# merge_num: 203, most_frequent_pair: (101, 99), new_token: b'ec'
# merge_num: 204, most_frequent_pair: (108, 121), new_token: b'ly'
# merge_num: 205, most_frequent_pair: (114, 97), new_token: b'ra'
# merge_num: 206, most_frequent_pair: (297, 305), new_token: b' gir'
# merge_num: 207, most_frequent_pair: (333, 100), new_token: b'ood'
# merge_num: 208, most_frequent_pair: (105, 99), new_token: b'ic'
# merge_num: 209, most_frequent_pair: (463, 108), new_token: b' girl'
# merge_num: 210, most_frequent_pair: (278, 302), new_token: b' can'
# merge_num: 211, most_frequent_pair: (336, 111), new_token: b' ro'
# merge_num: 212, most_frequent_pair: (265, 357), new_token: b' ball'
# merge_num: 213, most_frequent_pair: (116, 264), new_token: b'ted'
# merge_num: 214, most_frequent_pair: (260, 101), new_token: b' se'
# merge_num: 215, most_frequent_pair: (109, 121), new_token: b'my'
# merge_num: 216, most_frequent_pair: (293, 100), new_token: b'ard'
# merge_num: 217, most_frequent_pair: (263, 305), new_token: b' their'
# merge_num: 218, most_frequent_pair: (278, 387), new_token: b' could'
# merge_num: 219, most_frequent_pair: (119, 280), new_token: b'way'
# merge_num: 220, most_frequent_pair: (399, 110), new_token: b' kn'
# merge_num: 221, most_frequent_pair: (268, 292), new_token: b' him'
# merge_num: 222, most_frequent_pair: (331, 264), new_token: b' played'
# merge_num: 223, most_frequent_pair: (293, 107), new_token: b'ark'
# merge_num: 224, most_frequent_pair: (32, 415), new_token: b' out'
# merge_num: 225, most_frequent_pair: (63, 34), new_token: b'?"'
# merge_num: 226, most_frequent_pair: (276, 101), new_token: b' le'
# merge_num: 227, most_frequent_pair: (257, 100), new_token: b'hed'
# merge_num: 228, most_frequent_pair: (117, 109), new_token: b'um'
# merge_num: 229, most_frequent_pair: (97, 270), new_token: b'ain'
# merge_num: 230, most_frequent_pair: (263, 109), new_token: b' them'
# merge_num: 231, most_frequent_pair: (257, 110), new_token: b'hen'
# merge_num: 232, most_frequent_pair: (97, 120), new_token: b'ax'
# merge_num: 233, most_frequent_pair: (269, 114), new_token: b' fr'
# merge_num: 234, most_frequent_pair: (290, 100), new_token: b' sad'
# merge_num: 235, most_frequent_pair: (259, 273), new_token: b' are'
# merge_num: 236, most_frequent_pair: (39, 116), new_token: b"'t"
# merge_num: 237, most_frequent_pair: (397, 121), new_token: b' boy'
# merge_num: 238, most_frequent_pair: (297, 111), new_token: b' go'
# merge_num: 239, most_frequent_pair: (300, 370), new_token: b'other'
# merge_num: 240, most_frequent_pair: (459, 101), new_token: b' tree'
# merge_num: 241, most_frequent_pair: (295, 355), new_token: b' have'
# merge_num: 242, most_frequent_pair: (278, 108), new_token: b' cl'

# %%
merges
# Out:
# [(104, 101),
#  (32, 116),
#  (32, 97),
#  (32, 115),
#  (32, 119),
#  (110, 100),
#  (258, 257),
#  (101, 100),
#  (32, 98),
#  (258, 111),
#  (259, 262),
#  (32, 104),
#  (32, 102),
#  (105, 110),
#  (261, 97),
#  (32, 84),
#  (114, 101),
#  (105, 116),
#  (111, 117),
#  (32, 108),
#  (32, 100),
#  (32, 99),
#  (32, 112),
#  (97, 121),
#  (271, 115),
#  (101, 114),
#  (32, 109),
#  (111, 109),
#  (32, 257),
#  (272, 257),
#  (105, 115),
#  (32, 110),
#  (111, 110),
#  (260, 97),
#  (108, 108),
#  (105, 109),
#  (97, 114),
#  (105, 100),
#  (268, 97),
#  (32, 83),
#  (32, 103),
#  (97, 116),
#  (270, 103),
#  (111, 116),
#  (101, 110),
#  (97, 110),
#  (108, 101),
#  (111, 114),
#  (105, 114),
#  (32, 72),
#  (97, 109),
#  (101, 116),
#  (258, 104),
#  (32, 274),
#  (105, 103),
#  (105, 108),
#  (286, 121),
#  (306, 101),
#  (32, 270),
#  (32, 34),
#  (279, 108),
#  (114, 105),
#  (118, 282),
#  (111, 119),
#  (32, 117),
#  (117, 116),
#  (277, 280),
#  (290, 294),
#  (112, 112),
#  (32, 121),
#  (101, 115),
#  (274, 104),
#  (79, 110),
#  (261, 328),
#  (317, 280),
#  (32, 111),
#  (111, 111),
#  (285, 114),
#  (107, 264),
#  (32, 114),
#  (32, 73),
#  (296, 257),
#  (268, 287),
#  (265, 101),
#  (260, 116),
#  (108, 100),
#  (272, 292),
#  (99, 101),
#  (110, 116),
#  (32, 101),
#  (265, 311),
#  (99, 107),
#  (326, 275),
#  (319, 121),
#  (107, 101),
#  (295, 325),
#  (101, 262),
#  (32, 289),
#  (118, 101),
#  (117, 110),
#  (97, 291),
#  (312, 121),
#  (32, 76),
#  (318, 353),
#  (269, 360),
#  (321, 112),
#  (271, 345),
#  (276, 105),
#  (263, 121),
#  (295, 100),
#  (277, 111),
#  (261, 101),
#  (288, 300),
#  (257, 114),
#  (274, 116),
#  (332, 102),
#  (32, 66),
#  (97, 100),
#  (352, 121),
#  (115, 116),
#  (32, 77),
#  (309, 298),
#  (115, 101),
#  (290, 119),
#  (329, 101),
#  (283, 284),
#  (301, 116),
#  (32, 350),
#  (371, 303),
#  (276, 385),
#  (275, 342),
#  (269, 304),
#  (39, 115),
#  (260, 111),
#  (260, 257),
#  (260, 104),
#  (292, 101),
#  (258, 393),
#  (46, 34),
#  (288, 307),
#  (265, 111),
#  (99, 104),
#  (32, 107),
#  (288, 101),
#  (263, 273),
#  (305, 100),
#  (275, 262),
#  (359, 358),
#  (396, 264),
#  (265, 402),
#  (260, 109),
#  (363, 264),
#  (361, 115),
#  (118, 264),
#  (368, 273),
#  (272, 284),
#  (84, 257),
#  (265, 322),
#  (275, 116),
#  (33, 34),
#  (259, 110),
#  (101, 108),
#  (104, 116),
#  (108, 112),
#  (266, 111),
#  (294, 101),
#  (97, 108),
#  (285, 420),
#  (337, 116),
#  (329, 344),
#  (259, 291),
#  (261, 104),
#  (284, 101),
#  (32, 65),
#  (261, 383),
#  (276, 111),
#  (117, 103),
#  (276, 333),
#  (32, 287),
#  (362, 289),
#  (97, 351),
#  (116, 282),
#  (114, 121),
#  (117, 101),
#  (111, 273),
#  (266, 121),
#  (269, 356),
#  (103, 308),
#  (105, 291),
#  (105, 262),
#  (444, 370),
#  (278, 298),
#  (259, 115),
#  (265, 97),
#  (259, 116),
#  (32, 273),
#  (307, 101),
#  (266, 447),
#  (32, 106),
#  (277, 294),
#  (117, 114),
#  (367, 103),
#  (258, 273),
#  (101, 99),
#  (108, 121),
#  (114, 97),
#  (297, 305),
#  (333, 100),
#  (105, 99),
#  (463, 108),
#  (278, 302),
#  (336, 111),
#  (265, 357),
#  (116, 264),
#  (260, 101),
#  (109, 121),
#  (293, 100),
#  (263, 305),
#  (278, 387),
#  (119, 280),
#  (399, 110),
#  (268, 292),
#  (331, 264),
#  (293, 107),
#  (32, 415),
#  (63, 34),
#  (276, 101),
#  (257, 100),
#  (117, 109),
#  (97, 270),
#  (263, 109),
#  (257, 110),
#  (97, 120),
#  (269, 114),
#  (290, 100),
#  (259, 273),
#  (39, 116),
#  (397, 121),
#  (297, 111),
#  (300, 370),
#  (459, 101),
#  (295, 355),
#  (278, 108)]
